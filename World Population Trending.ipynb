# %% [markdown]
# # Setup
# According to the United Nations, the world population has reached 8 billion on November 15, 2022.
#
# In this assignment, we’ll explore the global population trends from the World Bank (https://data.worldbank.org/). The dataset we’ll use (population.csv) is based on Population Estimates and Projections and was last updated on 07/01/2022.
#
# Load the dataset into a dataframe population and look at the first and last few rows to get some initial idea of its content. You should then be able to answer the questions below.

# %% [markdown]
# Load the dataset into a dataframe _population_ and look at the first and last few rows to get some initial idea of its content.  You should then be able to answer the questions below.

# %%
import pandas as pd

# %%
# setup and peek at the first 10 rows
population = pd.read_csv('population.csv')
population.head(10)
# Out:
#   Country Name Country Code                                 Group     2001  \
# 0  Afghanistan          AFG            Population ages 0-14, male  5411610
# 1  Afghanistan          AFG          Population ages 0-14, female  5137506
# 2   Azerbaijan          AZE         Population ages 15-64, female  2671749
# 3   Azerbaijan          AZE           Population ages 15-64, male  2500099
# 4  Afghanistan          AFG         Population ages 15-64, female  5097016
# 5     Zimbabwe          ZWE  Population ages 65 and above, female   218576
# 6     Zimbabwe          ZWE    Population ages 65 and above, male   143066
# 7  Afghanistan          AFG           Population ages 15-64, male  5469968
# 8  Afghanistan          AFG  Population ages 65 and above, female   254716
# 9  Afghanistan          AFG    Population ages 65 and above, male   236176
#
#       2002     2003     2004     2005     2006     2007  ...     2012  \
# 0  5640277  5885568  6114720  6301959  6511422  6688306  ...  7500396
# ...

# %%
# peek at the last 10 rows
population.tail(10)
# Out:
#        Country Name Country Code                                 Group  \
# 1148         Zambia          ZMB           Population ages 15-64, male
# 1149         Zambia          ZMB  Population ages 65 and above, female
# 1150         Zambia          ZMB    Population ages 65 and above, male
# 1151       Zimbabwe          ZWE            Population ages 0-14, male
# 1152       Zimbabwe          ZWE          Population ages 0-14, female
# 1153  United States          USA            Population ages 0-14, male
# 1154  United States          USA          Population ages 0-14, female
# 1155  United States          USA         Population ages 15-64, female
# 1156       Zimbabwe          ZWE         Population ages 15-64, female
# 1157       Zimbabwe          ZWE           Population ages 15-64, male
#
#           2001      2002      2003      2004      2005      2006       2007  \
# 1148   2698957   2760484   2824050   2890970   2962395   3030920    3106200
# ...

# %% [markdown]
# ## Question 1
# How many countries are represented?

# %%
# Question 1
print(len(population.loc[:, 'Country Name'].drop_duplicates()))
# Out:
# 193

# %% [markdown]
# ## Question 2
# How many population groups are included?

# %%
# Question 2
print(len(population.groupby("Group")))
# Out:
# 6

# %% [markdown]
# # World Population

# %% [markdown]
# ## Question 3
# Based on this data, what was the total population of the world in 2021?

# %%
# Question 3
population['2021'].sum()
# Out:
# 7806700184

# %% [markdown]
# ## Question 4
# Plot the total population of the world in billions for 2001 through 2021.  Include the x and y labels and a title.
# The title should be: World Population.
# The x axis label should be 'Year'.
# The y axis label should be 'Population in Billions).  The y axis numbers will range from 6.25 5o 7.75.
#
# Use the fivethirtyeight style.
# Make sure you don't output any unnecessary text.

# %%
# Question 4
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
world_total_population = population.loc[:, '2001':'2021'].sum() / 1e9
world_total_population.loc['2021']
world_total_population.plot(title='World Population', xlabel='Year', ylabel='Population in Billions');

# %% [markdown]
# ## Question 5
# What was the percentage of female to the total world population in 2021?  Use a boolean mask with str.contains to find the answer.  Make sure your answer is a percentage.

# %%
# Question 5
(population[population['Group'].str.contains('female')]['2021'].sum()) / (population.loc[:, '2021'].sum()) * 100
# Out:
# 49.58292262758172

# %% [markdown]
# ## Question 6
# Plot the percentage of the younger population (0-14) to the total world population from 2001 through 2021.
# Use a boolean mask with str.contains to find the answer.
# Include the x and y labels and a title. Use the fivethirtyeight style.

# %%
# Question 6
percentage_of_younger = (population[population['Group'].str.contains('0-14')].loc[:, '2001':'2021'].sum()) / (population.loc[:, '2001':'2021'].sum()) * 100
percentage_of_younger.plot(title="Younger Population Decline",
                            xlabel='Year',
                            ylabel='Percentage of Younger Population');

# %% [markdown]
# # Population by Country

# %% [markdown]
# ## Question 7
# What is the total population of the United States in 2021?

# %%
# Question 7
population.loc[population['Country Name'] == 'United States','2021'].sum()
# Out:
# 331893745

# %% [markdown]
# ## Question 8
# Create a dataframe, _total_population_, showing the total population (across all groups) of each country for all the years.  Display the dataframe.

# %%
# Question 8
total_population = population.groupby('Country Name').sum()
total_population
# Out:
#                            2001      2002      2003      2004      2005  \
# Country Name
# Afghanistan            21606992  22600774  23680871  24726689  25654274
# Albania                 3060173   3051010   3039616   3026939   3011487
# Algeria                31451513  31855110  32264159  32692153  33149720
# Angola                 16945753  17519418  18121477  18758138  19433604
# Antigua and Barbuda       77212     78298     79311     80347     81462
# ...                         ...       ...       ...       ...       ...
# Virgin Islands (U.S.)    108549    108509    108505    108467    108453
# West Bank and Gaza      2997784   3075372   3154969   3236627   3320396
# Yemen, Rep.            17918369  18443684  18985001  19540096  20107416
# Zambia                 10692197  10971704  11256740  11550641  11856244
# Zimbabwe               11923906  11954293  11982219  12019911  12076697
#
#                            2006      2007      2008      2009      2010  ...  \
# ...

# %% [markdown]
# ## Question 9
# Create a dataframe, _top_five_, showing the total population of the 5 most populous coutries in 2021.
# Even though the countries are ranked based on their 2021 population, the dataframe must include data for all years.
#
# Display the dataframe.

# %%
# Question 9
top_five = total_population.sort_values(ascending=False, by='2021').iloc[0:5]
top_five
# Out:
#                      2001        2002        2003        2004        2005  \
# Country Name
# China          1271850001  1280400001  1288400001  1296075000  1303720000
# India          1075000094  1093317187  1111523146  1129623466  1147609924
# United States   284968955   287625192   290107933   292805297   295516600
# Indonesia       214427419   217357790   220309473   223285666   226289468
# Pakistan        145978408   149549695   153093371   156664698   160304007
#
#                      2006        2007        2008        2009        2010  \
# Country Name
# China          1311020000  1317885000  1324655000  1331260000  1337705000
# India          1165486291  1183209471  1200669762  1217726217  1234281163
# United States   298379912   301231206   304093967   306771529   309327143
# Indonesia       229318262   232374239   235469755   238620554   241834226
# Pakistan        164022626   167808106   171648984   175525610   179424643
#
# ...

# %% [markdown]
# ## Question 10
# Plot the total population, in billions, of the 5 most populous countries from 2001 to 2021.
# Make sure your plot includes a title, a legend and labels for both axes.
#
# Hint: You may use a for loop to loop over top_five.index.

# %%
# Question 10
top_five = top_five / 1e9
for country in top_five.index:
    top_five.loc[country].plot(title="Population Growth in the 5 most populous countries",
                               legend=True,
                               ylabel="Population in Billions",
                               xlabel="Year");

# %% [markdown]
# ## Question 11
# Use a bar graph to show the population of the 5 most populous countries in 2021. Make sure your plot includes a title, and labels for both axes. Use different colors for each country: blue for the US, yellow for China, orange for India, red for Indonesia and green for Pakistan.

# %%
# Question 11
for country in top_five.index:
    top_five["2021"].plot(kind="bar",
                           title="The Most Populous Countries In 2021",
                           ylabel="Population in Billions",
                           xlabel="Country",
                         color=['yellow','orange','blue','red','green']);

# %% [markdown]
# ## Question 12
# Which country had the largest percentage decrease in population between 2001 and 2021.
# To calulate the percentage decrease, take the difference between 2001 and 2021 and divide by the 2001 value.
# Your answer must be a string.
#
# Hint: Use the total_population dataframe that you created in Question 8.

# %%
# Question 12
((total_population['2001'] - total_population['2021']) / total_population['2001'] * 100).idxmax(axis=0)
# Out:
# 'Lithuania'

# %% [markdown]
# ## Question 13
# What is the largest percentage growth in population that occured for a country between 2001 and 2021?
#
# Your answer must be a percentage - not a country name.

# %%
# Question 13
((total_population['2021'] - total_population['2001']) / total_population['2001'] * 100).max()
# Out:
# 376.49789516644364

# %% [markdown]
# # Population by Age

# %% [markdown]
# ## Question 14
# Create a dataframe, active_population, that shows for each country, the total 'working age' population (Population ages 15-64).
# Use a set for the working age groups.
# Use the _query_ method to select the relevant rows.
# Display the dataframe after you create it.

# %%
# Question 14
working_age_df = population[population['Group'].str.contains('Population ages 15-64')]
working_ages_set = set(working_age_df['Group'])
active_population = population.query('Group in @working_ages_set').groupby('Country Name').sum()
active_population
# Out:
#                            2001      2002      2003      2004      2005  \
# Country Name
# Afghanistan            10566984  11096718  11684917  12267601  12804784
# Albania                 1928412   1936581   1944494   1951930   1957419
# Algeria                19626395  20193038  20746612  21296414  21841623
# Angola                  8513770   8811569   9130229   9470298   9831386
# Antigua and Barbuda       50303     51299     52233     53177     54179
# ...                         ...       ...       ...       ...       ...
# Virgin Islands (U.S.)     71830     72334     72593     72670     72706
# West Bank and Gaza      1506280   1555705   1608280   1664881   1725161
# Yemen, Rep.             8756806   9113407   9484401   9882132  10310477
# Zambia                  5459298   5589367   5724177   5865871   6016443
# Zimbabwe                6567452   6603531   6638779   6673024   6707635
#
#                            2006      2007      2008      2009      2010  ...  \
# ...

# %% [markdown]
# ## Question 15
# What country has the largest number of working age people (15-64) in 2021?
# Hint:  use the active_population dataframe created in Question 14.

# %%
# Question 15
active_population.sort_values(ascending=False, by='2021').index[0]
# Out:
# 'China'

# %% [markdown]
# ## Question 16
# Create a pivot table, _pivot_, showing for each country the population in each group for 2021.  The column headers should be the groups. Display the pivot table.

# %%
# Question 16
pivot = population.pivot_table(index='Country Name', columns='Group', values='2021')
pivot
# Out:
# Group                  Population ages 0-14, female  \
# Country Name
# Afghanistan                                 8010458
# Albania                                      227640
# Algeria                                     6753074
# Angola                                      7790007
# Antigua and Barbuda                           10582
# ...                                             ...
# Virgin Islands (U.S.)                          9862
# West Bank and Gaza                           912996
# Yemen, Rep.                                 5740162
# Zambia                                      4083535
# Zimbabwe                                    3105771
#
# Group                  Population ages 0-14, male  \
# Country Name
# Afghanistan                               8401013
# Albania                                    252463
# Algeria                                   7040198
# Angola                                    7870657
# Antigua and Barbuda                         10875
# ...

# %% [markdown]
# ## Question 17
# Using the pivot table created in Q16, create a pie chart that shows the composition of the USA population.

# %%
# Question 17
pivot.loc['United States'].plot(kind='pie', title="USA Population Groups in 2021");

# %% [markdown]
# # Population Density

# %% [markdown]
# In this part we'll use the land.csv dataset which is based on the Land area (sq. km) downloaded from the World Bank data catalog.
#
# Load the dataset into a dataframe _land_ and look at the first  10 rows to get some initial idea of its content.

# %%
# load the land.csv file
land = pd.read_csv('land.csv')
land.head(10)
# Out:
#          Country Name Code        Area
# 0  Russian Federation  RUS  16376870.0
# 1               China  CHN   9424702.9
# 2       United States  USA   9147420.0
# 3              Canada  CAN   8965590.0
# 4              Brazil  BRA   8358140.0
# 5           Australia  AUS   7692020.0
# 6               India  IND   2973190.0
# 7           Argentina  ARG   2736690.0
# 8          Kazakhstan  KAZ   2699700.0
# 9             Algeria  DZA   2381741.0

# %% [markdown]
# ## Question 18
# Combine the land dataframe with the _total_population_ dataframe that you created in Question 8.  Name the resulting dataframe _countries_.  Display the _countries_ dataframe.

# %%
# Question 18
countries = pd.merge(left=land, right=total_population, left_on="Country Name", right_on="Country Name")
countries.set_index('Country Name', inplace=True)
countries
# Out:
#                    Code        Area        2001        2002        2003  \
# Country Name
# Russian Federation  RUS  16376870.0   145976483   145306497   144648618
# China               CHN   9424702.9  1271850001  1280400001  1288400001
# United States       USA   9147420.0   284968955   287625192   290107933
# Canada              CAN   8965590.0    31020902    31360079    31644028
# Brazil              BRA   8358140.0   177196051   179537523   181809244
# ...                 ...         ...         ...         ...         ...
# Grenada             GRD       340.0      103242      103636      104003
# Malta               MLT       320.0      393028      395968      398583
# Maldives            MDV       300.0      286309      294185      302681
# Aruba               ABW       180.0       92892       94992       97016
# Macao SAR, China    MAC        32.9      437928      448813      460157
#
#                           2004        2005        2006        2007  \
# Country Name
# ...

# %% [markdown]
# ## Question 19
# We define the population density as the total population of a country in 2021 divided by the land area in sq. km.
# Add a column, _Density_,  to the countries dataframe that shows the population density of each country.  Display the _countries_ dataframe.

# %%
# Question 19
countries['Density'] = countries['2021'] / countries['Area']
countries
# Out:
#                    Code        Area        2001        2002        2003  \
# Country Name
# Russian Federation  RUS  16376870.0   145976483   145306497   144648618
# China               CHN   9424702.9  1271850001  1280400001  1288400001
# United States       USA   9147420.0   284968955   287625192   290107933
# Canada              CAN   8965590.0    31020902    31360079    31644028
# Brazil              BRA   8358140.0   177196051   179537523   181809244
# ...                 ...         ...         ...         ...         ...
# Grenada             GRD       340.0      103242      103636      104003
# Malta               MLT       320.0      393028      395968      398583
# Maldives            MDV       300.0      286309      294185      302681
# Aruba               ABW       180.0       92892       94992       97016
# Macao SAR, China    MAC        32.9      437928      448813      460157
#
#                           2004        2005        2006        2007  \
# Country Name
# ...

# %% [markdown]
# ## Question 20
# What are the 10 countries with the highest population density (with the highest one first)?
# Your result should show a dataframe with the country names and the corresponding densities.  There is no need to show the yearly population totals, the Area or the country codes.

# %%
# Question 20
countries.sort_values(ascending=False, by='Density').iloc[0:10, [-1]]
# Out:
#                            Density
# Country Name
# Macao SAR, China      20011.884498
# Singapore              7595.497214
# Hong Kong SAR, China   7060.095238
# Bahrain                2227.127389
# Maldives               1812.066667
# Malta                  1615.215625
# Bangladesh             1277.586956
# West Bank and Gaza      817.732392
# Barbados                669.088372
# Lebanon                 661.696090
